# %%
import numpy as np

# %%
class Node(object):
    def __init__(self, inbound_nodes = []):
        self.inbound_nodes = inbound_nodes
        self.outbound_nodes = []
        
        for node in self.inbound_nodes:
            node.outbound_nodes.append(self)
    
        self.value = None
        self.gradients = {}
    
    def forward(self):
        raise NotImplementedError
        
    def backward(self):
        raise NotImplementedError
        
        
class Placeholder(Node):
    def __init__(self):
        Node.__init__(self)
        
    def forward(self, value=None):
        if value is not None:
            self.value = value
            
    def backward(self):
        self.gradients = {self: 0}
        for n in self.outbound_nodes:
            grad_cost = n.gradients[self]
            self.gradients[self] += grad_cost * 1
            
class Variable(Node):
    def __init__(self, value):
        Node.__init__(self)
    
        self.value = value
        
    def forward(self):
        pass
    
    def backward(self):
        self.gradients = {self: 0}
        for n in self.outbound_nodes:
            grad_cost = n.gradients[self]
            self.gradients[self] += grad_cost * 1
            
class Add(Node):
    def __init__(self, *inputs):
        Node.__init__(self, list(inputs))
        
    def forward(self):
        self.value = sum(val.value for val in self.inbound_nodes)
                     
class Mul(Node):
    def __init__(self, *inputs):
        Node.__init__(self, list(inputs))
        
    def forward(self):
        self.value = np.prod(np.array([val.value for val in self.inbound_nodes]))

class Linear(Node):
    def __init__(self, inputs, weights, bias):
        Node.__init__(self, [inputs, weights, bias])
        
    def forward(self):
        self.value = np.dot(self.inbound_nodes[0].value, self.inbound_nodes[1].value) \
                + self.inbound_nodes[2].value

    def backward(self):
        self.gradients = {n: np.zeros_like(n.value) for n in self.inbound_nodes}

        for n in self.outbound_nodes:
            grad_cost = n.gradients[self]
       
            self.gradients[self.inbound_nodes[0]] += np.dot(grad_cost, self.inbound_nodes[1].value.T)
            self.gradients[self.inbound_nodes[1]] += np.dot(self.inbound_nodes[0].value.T, grad_cost)
            self.gradients[self.inbound_nodes[2]] += np.sum(grad_cost, axis=0, keepdims=False)


            
class Sigmoid(Node):
    def __init__(self, node):
        Node.__init__(self, [node])

    def _sigmoid(self, x):
        return 1.0 / (1.0 + np.exp(-x))

    def forward(self):
        self.value = self._sigmoid(self.inbound_nodes[0].value)
        
    def backward(self):
        self.gradients = {n: np.zeros_like(n.value) for n in self.inbound_nodes}
        for n in self.outbound_nodes:
            grad_cost = n.gradients[self]
            self.gradients[self.inbound_nodes[0]] += grad_cost * self.value * (1.0 - self.value)

        
class MSE(Node):
    def __init__(self, y, a):
        Node.__init__(self, [y, a])

    def forward(self):
        y = self.inbound_nodes[0].value.reshape(-1, 1)
        a = self.inbound_nodes[1].value.reshape(-1, 1)
        self.diff = y - a
        self.m = self.inbound_nodes[0].value.shape[0]
        self.value = np.sum(np.square(y - a)) / self.m
        pass
    
    def backward(self):
        self.gradients[self.inbound_nodes[0]] = (2 / self.m) * self.diff
        self.gradients[self.inbound_nodes[1]] = (-2 / self.m) * self.diff

# %%
def topological_sort(feed_dict):
    input_nodes = [n for n in feed_dict.keys()]

    G = {}
    nodes = [n for n in input_nodes]
    while len(nodes) > 0:
        n = nodes.pop(0)
        if n not in G:
            G[n] = {'in': set(), 'out': set()}
        for m in n.outbound_nodes:
            if m not in G:
                G[m] = {'in': set(), 'out': set()}
            G[n]['out'].add(m)
            G[m]['in'].add(n)
            nodes.append(m)

    L = []
    S = set(input_nodes)
    while len(S) > 0:
        n = S.pop()

        if isinstance(n, Placeholder):
            n.value = feed_dict[n]

        L.append(n)
        for m in n.outbound_nodes:
            G[n]['out'].remove(m)
            G[m]['in'].remove(n)
            # if no other incoming edges add to S
            if len(G[m]['in']) == 0:
                S.add(m)
    return L

# %%
x, y =  Placeholder(), Placeholder()

add = Add(x, y)
feed_dict = {x : 10,  y : 20 }
sorted_nodes = topological_sort(feed_dict = feed_dict)


def forward_pass(output_node, sorted_nodes):
    for n in sorted_nodes:
        n.forward()

    return output_node.value

def forward_and_backward(graph):
    for n in graph:
        n.forward()
    
    for n in graph[::-1]:
        n.backward()
        
def sgd_update(trainables, learning_rate=1e-2):
    for t in trainables:
        t.value -= learning_rate * t.gradients[t]
    pass

# %%
mu, sigma = 0, 0.1
    
X, y = Placeholder(), Placeholder()
W1, b1 = Variable(np.random.normal(mu, sigma, (2, 5))), Variable(np.random.normal(mu, sigma, (5)))
W2, b2 = Variable(np.random.normal(mu, sigma, (5, 1))), Variable(np.random.normal(mu, sigma, (1)))

l1 = Linear(X, W1, b1)
s1 = Sigmoid(l1)
l2 = Linear(s1, W2, b2)
cost = MSE(l2, y)

X_ = np.array([[-1., -2.], [-1, -2]])
y_ = np.array([1, 2])

feed_dict = {
    X: X_,
    y: y_ ,
    W1 : None,
    b1: None,
    W2 : None,
    b2: None,
}

graph = topological_sort(feed_dict)

print (graph)

forward_and_backward(graph)

print (cost.value)
print (X.outbound_nodes)

gradients = [t.gradients[t] for t in [X, y, W1, b1, W2, b2]]

print(gradients)

forward_and_backward(graph)
print (cost.value)
forward_and_backward(graph)
print (cost.value)
forward_and_backward(graph)
print (cost.value)
# Out:
# [<__main__.Variable object at 0x0000021FC571E898>, <__main__.Placeholder object at 0x0000021FC571E4A8>, <__main__.Placeholder object at 0x0000021FC571E8D0>, <__main__.Variable object at 0x0000021FC571E358>, <__main__.Variable object at 0x0000021FC571E5C0>, <__main__.Variable object at 0x0000021FC571EDD8>, <__main__.Linear object at 0x0000021FC571EC18>, <__main__.Sigmoid object at 0x0000021FC571EF60>, <__main__.Linear object at 0x0000021FC571EF28>, <__main__.MSE object at 0x0000021FC571EFD0>]
# 2.31231747044
# [<__main__.Linear object at 0x0000021FC571EC18>]
# [array([[ 0.00048625,  0.0061361 ],
#        [ 0.0010057 ,  0.01269123]]), array([[ 0.93607711],
#        [ 1.93607711]]), array([[ 0.03037664, -0.07852801,  0.09250184, -0.00452026,  0.00383185],
#        [ 0.06075327, -0.15705602,  0.18500368, -0.00904052,  0.0076637 ]]), array([-0.03037664,  0.07852801, -0.09250184,  0.00452026, -0.00383185]), array([[-1.92010901],
#        [-1.51600467],
#        [-1.7258849 ],
#        [-1.38240431],
#        [-1.20235553]]), array([-2.87215422])]
# 2.31231747044
# 2.31231747044
# 2.31231747044

# %%
import numpy as np
from sklearn.datasets import load_boston
from sklearn.utils import shuffle, resample

# Load data
data = load_boston()

X_ = data['data']
y_ = data['target']

# Normalize data
X_ = (X_ - np.mean(X_, axis=0)) / np.std(X_, axis=0)

n_features = X_.shape[1]
n_hidden = 10

mu, sigma = 0, 0.1
    
X, y = Placeholder(), Placeholder()
W1, b1 = Variable(np.random.normal(mu, sigma, (n_features, n_hidden))), Variable(np.random.normal(mu, sigma, (n_hidden)))
W2, b2 = Variable(np.random.normal(mu, sigma, (n_hidden, 1))), Variable(np.random.normal(mu, sigma, (1)))

l1 = Linear(X, W1, b1)
s1 = Sigmoid(l1)
l2 = Linear(s1, W2, b2)
cost = MSE(l2, y)


feed_dict = {
    X: X_,
    y: y_ ,
    W1 : None,
    b1: None,
    W2 : None,
    b2: None,
}


epochs = 1090
# Total number of examples
m = X_.shape[0]

batch_size = 11
steps_per_epoch = m // batch_size

graph = topological_sort(feed_dict)
trainables = [W1, b1, W2, b2]

print("Total number of examples = {}".format(m))

# Step 4
for i in range(epochs):
    loss = 0
    for j in range(steps_per_epoch):
        # Step 1
        # Randomly sample a batch of examples
        X_batch, y_batch = resample(X_, y_, n_samples=batch_size)

        # Reset value of X and y Inputs
        X.value = X_batch
        y.value = y_batch

        # Step 2
        forward_and_backward(graph)

        # Step 3
        sgd_update(trainables, 0.01)

        loss += graph[-1].value

    print("Epoch: {}, Loss: {:.3f}".format(i+1, loss/steps_per_epoch))
# Out:
# Total number of examples = 506
# Epoch: 1, Loss: 108.988
# Epoch: 2, Loss: 33.833
# Epoch: 3, Loss: 26.047
# Epoch: 4, Loss: 27.612
# Epoch: 5, Loss: 25.595
# Epoch: 6, Loss: 21.142
# Epoch: 7, Loss: 16.972
# Epoch: 8, Loss: 18.198
# Epoch: 9, Loss: 13.070
# Epoch: 10, Loss: 13.922
# Epoch: 11, Loss: 13.354
# Epoch: 12, Loss: 12.371
# Epoch: 13, Loss: 16.164
# Epoch: 14, Loss: 11.801
# Epoch: 15, Loss: 10.918
# Epoch: 16, Loss: 14.995
# Epoch: 17, Loss: 11.945
# Epoch: 18, Loss: 12.300
# Epoch: 19, Loss: 11.247
# Epoch: 20, Loss: 13.156
# Epoch: 21, Loss: 10.711
# Epoch: 22, Loss: 11.379
# Epoch: 23, Loss: 11.247
# Epoch: 24, Loss: 8.591
# Epoch: 25, Loss: 8.535
# Epoch: 26, Loss: 9.445
# Epoch: 27, Loss: 7.935
# Epoch: 28, Loss: 10.067
# Epoch: 29, Loss: 10.589
# Epoch: 30, Loss: 9.826
# Epoch: 31, Loss: 11.094
# Epoch: 32, Loss: 9.410
# Epoch: 33, Loss: 11.571
# Epoch: 34, Loss: 7.423
# Epoch: 35, Loss: 11.034
# Epoch: 36, Loss: 10.288
# Epoch: 37, Loss: 7.106
# Epoch: 38, Loss: 10.808
# Epoch: 39, Loss: 10.790
# Epoch: 40, Loss: 8.257
# Epoch: 41, Loss: 8.382
# Epoch: 42, Loss: 8.443
# Epoch: 43, Loss: 9.199
# Epoch: 44, Loss: 6.958
# Epoch: 45, Loss: 9.657
# Epoch: 46, Loss: 8.007
# Epoch: 47, Loss: 9.567
# Epoch: 48, Loss: 6.631
# Epoch: 49, Loss: 8.298
# Epoch: 50, Loss: 8.093
# Epoch: 51, Loss: 7.403
# Epoch: 52, Loss: 8.285
# Epoch: 53, Loss: 8.804
# Epoch: 54, Loss: 8.874
# Epoch: 55, Loss: 8.520
# Epoch: 56, Loss: 7.037
# Epoch: 57, Loss: 6.731
# Epoch: 58, Loss: 6.528
# Epoch: 59, Loss: 7.412
# Epoch: 60, Loss: 6.802
# Epoch: 61, Loss: 7.451
# Epoch: 62, Loss: 6.628
# Epoch: 63, Loss: 7.646
# Epoch: 64, Loss: 6.749
# Epoch: 65, Loss: 6.762
# Epoch: 66, Loss: 6.338
# Epoch: 67, Loss: 7.006
# Epoch: 68, Loss: 7.005
# Epoch: 69, Loss: 7.263
# Epoch: 70, Loss: 7.816
# Epoch: 71, Loss: 7.451
# Epoch: 72, Loss: 7.577
# Epoch: 73, Loss: 6.853
# Epoch: 74, Loss: 6.735
# Epoch: 75, Loss: 5.119
# Epoch: 76, Loss: 7.012
# Epoch: 77, Loss: 5.714
# Epoch: 78, Loss: 6.393
# Epoch: 79, Loss: 6.500
# Epoch: 80, Loss: 6.910
# Epoch: 81, Loss: 6.583
# Epoch: 82, Loss: 6.389
# Epoch: 83, Loss: 6.750
# Epoch: 84, Loss: 6.129
# Epoch: 85, Loss: 6.182
# Epoch: 86, Loss: 6.866
# Epoch: 87, Loss: 5.972
# Epoch: 88, Loss: 6.514
# Epoch: 89, Loss: 6.196
# Epoch: 90, Loss: 6.096
# Epoch: 91, Loss: 6.446
# Epoch: 92, Loss: 6.280
# Epoch: 93, Loss: 7.787
# Epoch: 94, Loss: 6.704
# Epoch: 95, Loss: 5.947
# Epoch: 96, Loss: 6.533
# Epoch: 97, Loss: 6.677
# Epoch: 98, Loss: 5.538
# Epoch: 99, Loss: 6.427
# Epoch: 100, Loss: 5.863
# Epoch: 101, Loss: 5.074
# Epoch: 102, Loss: 5.113
# Epoch: 103, Loss: 7.323
# Epoch: 104, Loss: 5.941
# Epoch: 105, Loss: 6.171
# Epoch: 106, Loss: 5.893
# Epoch: 107, Loss: 5.844
# Epoch: 108, Loss: 6.755
# Epoch: 109, Loss: 5.794
# Epoch: 110, Loss: 4.588
# Epoch: 111, Loss: 6.091
# Epoch: 112, Loss: 5.769
# Epoch: 113, Loss: 6.484
# Epoch: 114, Loss: 5.441
# Epoch: 115, Loss: 5.156
# Epoch: 116, Loss: 5.518
# Epoch: 117, Loss: 6.255
# Epoch: 118, Loss: 5.863
# Epoch: 119, Loss: 5.396
# Epoch: 120, Loss: 5.705
# Epoch: 121, Loss: 5.459
# Epoch: 122, Loss: 5.845
# Epoch: 123, Loss: 6.295
# Epoch: 124, Loss: 4.648
# Epoch: 125, Loss: 6.079
# Epoch: 126, Loss: 4.925
# Epoch: 127, Loss: 4.733
# Epoch: 128, Loss: 4.821
# Epoch: 129, Loss: 5.509
# Epoch: 130, Loss: 6.755
# Epoch: 131, Loss: 5.848
# Epoch: 132, Loss: 5.625
# Epoch: 133, Loss: 5.354
# Epoch: 134, Loss: 4.701
# Epoch: 135, Loss: 5.079
# Epoch: 136, Loss: 5.250
# Epoch: 137, Loss: 6.393
# Epoch: 138, Loss: 5.689
# Epoch: 139, Loss: 4.914
# Epoch: 140, Loss: 5.492
# Epoch: 141, Loss: 4.768
# Epoch: 142, Loss: 5.707
# Epoch: 143, Loss: 5.358
# Epoch: 144, Loss: 4.977
# Epoch: 145, Loss: 6.479
# Epoch: 146, Loss: 4.993
# Epoch: 147, Loss: 5.278
# Epoch: 148, Loss: 5.438
# Epoch: 149, Loss: 5.979
# Epoch: 150, Loss: 4.759
# Epoch: 151, Loss: 4.255
# Epoch: 152, Loss: 5.609
# Epoch: 153, Loss: 5.136
# Epoch: 154, Loss: 4.359
# Epoch: 155, Loss: 5.165
# Epoch: 156, Loss: 5.151
# Epoch: 157, Loss: 4.971
# Epoch: 158, Loss: 4.735
# Epoch: 159, Loss: 4.707
# Epoch: 160, Loss: 4.815
# Epoch: 161, Loss: 5.539
# Epoch: 162, Loss: 5.644
# Epoch: 163, Loss: 5.201
# Epoch: 164, Loss: 5.842
# Epoch: 165, Loss: 4.762
# Epoch: 166, Loss: 5.049
# Epoch: 167, Loss: 4.327
# Epoch: 168, Loss: 4.713
# Epoch: 169, Loss: 4.952
# Epoch: 170, Loss: 5.275
# Epoch: 171, Loss: 4.564
# Epoch: 172, Loss: 5.045
# Epoch: 173, Loss: 4.507
# Epoch: 174, Loss: 4.554
# Epoch: 175, Loss: 4.022
# Epoch: 176, Loss: 4.507
# Epoch: 177, Loss: 4.980
# Epoch: 178, Loss: 5.014
# Epoch: 179, Loss: 5.048
# Epoch: 180, Loss: 4.435
# Epoch: 181, Loss: 4.486
# Epoch: 182, Loss: 4.488
# Epoch: 183, Loss: 4.912
# Epoch: 184, Loss: 3.665
# Epoch: 185, Loss: 5.402
# Epoch: 186, Loss: 4.732
# Epoch: 187, Loss: 4.975
# Epoch: 188, Loss: 4.157
# Epoch: 189, Loss: 4.493
# Epoch: 190, Loss: 4.195
# Epoch: 191, Loss: 5.150
# Epoch: 192, Loss: 5.202
# Epoch: 193, Loss: 4.635
# Epoch: 194, Loss: 5.085
# Epoch: 195, Loss: 4.240
# Epoch: 196, Loss: 4.658
# Epoch: 197, Loss: 4.830
# Epoch: 198, Loss: 4.372
# Epoch: 199, Loss: 4.270
# Epoch: 200, Loss: 4.363
# Epoch: 201, Loss: 4.953
# Epoch: 202, Loss: 4.594
# Epoch: 203, Loss: 4.143
# Epoch: 204, Loss: 4.423
# Epoch: 205, Loss: 4.600
# Epoch: 206, Loss: 5.131
# Epoch: 207, Loss: 4.203
# Epoch: 208, Loss: 4.569
# Epoch: 209, Loss: 4.627
# Epoch: 210, Loss: 4.087
# Epoch: 211, Loss: 3.969
# Epoch: 212, Loss: 3.869
# Epoch: 213, Loss: 3.951
# Epoch: 214, Loss: 4.457
# Epoch: 215, Loss: 4.445
# Epoch: 216, Loss: 4.605
# Epoch: 217, Loss: 4.398
# Epoch: 218, Loss: 4.877
# Epoch: 219, Loss: 4.093
# Epoch: 220, Loss: 4.342
# Epoch: 221, Loss: 4.402
# Epoch: 222, Loss: 4.608
# Epoch: 223, Loss: 3.970
# Epoch: 224, Loss: 3.892
# Epoch: 225, Loss: 5.293
# Epoch: 226, Loss: 4.088
# Epoch: 227, Loss: 4.719
# Epoch: 228, Loss: 4.145
# Epoch: 229, Loss: 3.877
# Epoch: 230, Loss: 4.816
# Epoch: 231, Loss: 3.702
# Epoch: 232, Loss: 4.591
# Epoch: 233, Loss: 5.053
# Epoch: 234, Loss: 3.980
# Epoch: 235, Loss: 4.054
# Epoch: 236, Loss: 5.049
# Epoch: 237, Loss: 4.125
# Epoch: 238, Loss: 4.230
# Epoch: 239, Loss: 4.518
# Epoch: 240, Loss: 3.791
# Epoch: 241, Loss: 5.030
# Epoch: 242, Loss: 4.567
# Epoch: 243, Loss: 3.737
# Epoch: 244, Loss: 4.143
# Epoch: 245, Loss: 3.815
# Epoch: 246, Loss: 4.427
# Epoch: 247, Loss: 4.097
# Epoch: 248, Loss: 4.561
# Epoch: 249, Loss: 4.502
# Epoch: 250, Loss: 3.781
# Epoch: 251, Loss: 4.321
# Epoch: 252, Loss: 4.252
# Epoch: 253, Loss: 3.518
# Epoch: 254, Loss: 4.633
# Epoch: 255, Loss: 4.434
# Epoch: 256, Loss: 4.088
# Epoch: 257, Loss: 3.577
# Epoch: 258, Loss: 4.472
# Epoch: 259, Loss: 4.472
# Epoch: 260, Loss: 4.280
# Epoch: 261, Loss: 4.000
# Epoch: 262, Loss: 3.477
# Epoch: 263, Loss: 3.591
# Epoch: 264, Loss: 3.638
# Epoch: 265, Loss: 4.549
# Epoch: 266, Loss: 4.349
# Epoch: 267, Loss: 3.872
# Epoch: 268, Loss: 3.933
# Epoch: 269, Loss: 4.400
# Epoch: 270, Loss: 3.880
# Epoch: 271, Loss: 4.793
# Epoch: 272, Loss: 4.618
# Epoch: 273, Loss: 3.407
# Epoch: 274, Loss: 4.186
# Epoch: 275, Loss: 3.966
# Epoch: 276, Loss: 4.019
# Epoch: 277, Loss: 3.383
# Epoch: 278, Loss: 4.504
# Epoch: 279, Loss: 3.730
# Epoch: 280, Loss: 3.756
# Epoch: 281, Loss: 3.211
# Epoch: 282, Loss: 3.906
# Epoch: 283, Loss: 4.818
# Epoch: 284, Loss: 3.264
# Epoch: 285, Loss: 4.088
# Epoch: 286, Loss: 3.985
# Epoch: 287, Loss: 3.679
# Epoch: 288, Loss: 3.601
# Epoch: 289, Loss: 4.766
# Epoch: 290, Loss: 4.116
# Epoch: 291, Loss: 4.046
# Epoch: 292, Loss: 4.111
# Epoch: 293, Loss: 3.146
# Epoch: 294, Loss: 3.805
# Epoch: 295, Loss: 3.600
# Epoch: 296, Loss: 3.473
# Epoch: 297, Loss: 4.048
# Epoch: 298, Loss: 4.392
# Epoch: 299, Loss: 3.860
# Epoch: 300, Loss: 4.890
# Epoch: 301, Loss: 4.417
# Epoch: 302, Loss: 4.085
# Epoch: 303, Loss: 3.673
# Epoch: 304, Loss: 4.125
# Epoch: 305, Loss: 3.538
# Epoch: 306, Loss: 3.657
# Epoch: 307, Loss: 4.163
# Epoch: 308, Loss: 3.977
# Epoch: 309, Loss: 2.973
# Epoch: 310, Loss: 4.072
# Epoch: 311, Loss: 3.855
# Epoch: 312, Loss: 3.187
# Epoch: 313, Loss: 3.998
# Epoch: 314, Loss: 3.972
# Epoch: 315, Loss: 3.543
# Epoch: 316, Loss: 3.557
# Epoch: 317, Loss: 4.610
# Epoch: 318, Loss: 3.772
# Epoch: 319, Loss: 3.759
# Epoch: 320, Loss: 3.447
# Epoch: 321, Loss: 3.913
# Epoch: 322, Loss: 3.357
# Epoch: 323, Loss: 3.926
# Epoch: 324, Loss: 3.587
# Epoch: 325, Loss: 3.590
# Epoch: 326, Loss: 4.244
# Epoch: 327, Loss: 3.737
# Epoch: 328, Loss: 3.954
# Epoch: 329, Loss: 3.955
# Epoch: 330, Loss: 3.580
# Epoch: 331, Loss: 3.698
# Epoch: 332, Loss: 3.627
# Epoch: 333, Loss: 3.790
# Epoch: 334, Loss: 3.306
# Epoch: 335, Loss: 3.358
# Epoch: 336, Loss: 4.302
# Epoch: 337, Loss: 3.640
# Epoch: 338, Loss: 3.241
# Epoch: 339, Loss: 3.153
# Epoch: 340, Loss: 3.951
# Epoch: 341, Loss: 3.570
# Epoch: 342, Loss: 3.697
# Epoch: 343, Loss: 3.482
# Epoch: 344, Loss: 4.270
# Epoch: 345, Loss: 3.962
# Epoch: 346, Loss: 3.569
# Epoch: 347, Loss: 3.316
# Epoch: 348, Loss: 3.475
# Epoch: 349, Loss: 4.465
# Epoch: 350, Loss: 3.725
# Epoch: 351, Loss: 3.742
# Epoch: 352, Loss: 3.523
# Epoch: 353, Loss: 3.637
# Epoch: 354, Loss: 3.800
# Epoch: 355, Loss: 3.661
# Epoch: 356, Loss: 3.551
# Epoch: 357, Loss: 3.871
# Epoch: 358, Loss: 3.997
# Epoch: 359, Loss: 4.115
# Epoch: 360, Loss: 4.740
# Epoch: 361, Loss: 3.789
# Epoch: 362, Loss: 3.740
# Epoch: 363, Loss: 3.814
# Epoch: 364, Loss: 3.737
# Epoch: 365, Loss: 3.827
# Epoch: 366, Loss: 4.032
# Epoch: 367, Loss: 3.757
# Epoch: 368, Loss: 3.335
# Epoch: 369, Loss: 3.617
# Epoch: 370, Loss: 2.995
# Epoch: 371, Loss: 4.423
# Epoch: 372, Loss: 3.908
# Epoch: 373, Loss: 3.631
# Epoch: 374, Loss: 3.839
# Epoch: 375, Loss: 3.851
# Epoch: 376, Loss: 3.517
# Epoch: 377, Loss: 3.952
# Epoch: 378, Loss: 3.104
# Epoch: 379, Loss: 4.023
# Epoch: 380, Loss: 3.949
# Epoch: 381, Loss: 3.782
# Epoch: 382, Loss: 3.490
# Epoch: 383, Loss: 3.852
# Epoch: 384, Loss: 3.388
# Epoch: 385, Loss: 3.082
# Epoch: 386, Loss: 3.823
# Epoch: 387, Loss: 3.660
# Epoch: 388, Loss: 3.702
# Epoch: 389, Loss: 4.283
# Epoch: 390, Loss: 4.146
# Epoch: 391, Loss: 3.631
# Epoch: 392, Loss: 3.430
# Epoch: 393, Loss: 3.399
# Epoch: 394, Loss: 3.599
# Epoch: 395, Loss: 3.568
# Epoch: 396, Loss: 3.201
# Epoch: 397, Loss: 3.580
# Epoch: 398, Loss: 3.802
# Epoch: 399, Loss: 4.520
# Epoch: 400, Loss: 3.435
# Epoch: 401, Loss: 3.677
# Epoch: 402, Loss: 3.708
# Epoch: 403, Loss: 3.511
# Epoch: 404, Loss: 3.804
# Epoch: 405, Loss: 3.163
# Epoch: 406, Loss: 3.428
# Epoch: 407, Loss: 3.692
# Epoch: 408, Loss: 3.396
# Epoch: 409, Loss: 3.773
# Epoch: 410, Loss: 3.414
# Epoch: 411, Loss: 3.766
# Epoch: 412, Loss: 3.702
# Epoch: 413, Loss: 3.346
# Epoch: 414, Loss: 4.056
# Epoch: 415, Loss: 3.377
# Epoch: 416, Loss: 3.232
# Epoch: 417, Loss: 3.338
# Epoch: 418, Loss: 3.276
# Epoch: 419, Loss: 3.890
# Epoch: 420, Loss: 3.477
# Epoch: 421, Loss: 4.001
# Epoch: 422, Loss: 3.877
# Epoch: 423, Loss: 3.237
# Epoch: 424, Loss: 3.251
# Epoch: 425, Loss: 3.809
# Epoch: 426, Loss: 3.399
# Epoch: 427, Loss: 3.445
# Epoch: 428, Loss: 3.627
# Epoch: 429, Loss: 3.448
# Epoch: 430, Loss: 3.387
# Epoch: 431, Loss: 3.897
# Epoch: 432, Loss: 3.774
# Epoch: 433, Loss: 3.649
# Epoch: 434, Loss: 2.911
# Epoch: 435, Loss: 3.754
# Epoch: 436, Loss: 3.804
# Epoch: 437, Loss: 3.638
# Epoch: 438, Loss: 3.365
# Epoch: 439, Loss: 3.911
# Epoch: 440, Loss: 4.106
# Epoch: 441, Loss: 3.650
# Epoch: 442, Loss: 3.522
# Epoch: 443, Loss: 3.056
# Epoch: 444, Loss: 3.450
# Epoch: 445, Loss: 3.935
# Epoch: 446, Loss: 4.160
# Epoch: 447, Loss: 3.402
# Epoch: 448, Loss: 2.917
# Epoch: 449, Loss: 3.349
# Epoch: 450, Loss: 3.626
# Epoch: 451, Loss: 3.661
# Epoch: 452, Loss: 3.116
# Epoch: 453, Loss: 3.336
# Epoch: 454, Loss: 3.498
# Epoch: 455, Loss: 3.716
# Epoch: 456, Loss: 3.614
# Epoch: 457, Loss: 3.273
# Epoch: 458, Loss: 3.196
# Epoch: 459, Loss: 3.730
# Epoch: 460, Loss: 3.414
# Epoch: 461, Loss: 3.609
# Epoch: 462, Loss: 3.991
# Epoch: 463, Loss: 3.807
# Epoch: 464, Loss: 3.521
# Epoch: 465, Loss: 3.656
# Epoch: 466, Loss: 3.520
# Epoch: 467, Loss: 4.081
# Epoch: 468, Loss: 3.224
# Epoch: 469, Loss: 3.616
# Epoch: 470, Loss: 3.629
# Epoch: 471, Loss: 3.678
# Epoch: 472, Loss: 3.417
# Epoch: 473, Loss: 3.374
# Epoch: 474, Loss: 3.422
# Epoch: 475, Loss: 3.653
# Epoch: 476, Loss: 3.881
# Epoch: 477, Loss: 3.491
# Epoch: 478, Loss: 3.983
# Epoch: 479, Loss: 3.693
# Epoch: 480, Loss: 3.275
# Epoch: 481, Loss: 3.710
# Epoch: 482, Loss: 3.304
# Epoch: 483, Loss: 3.662
# Epoch: 484, Loss: 3.308
# Epoch: 485, Loss: 3.572
# Epoch: 486, Loss: 3.341
# Epoch: 487, Loss: 3.720
# Epoch: 488, Loss: 3.221
# Epoch: 489, Loss: 3.737
# Epoch: 490, Loss: 3.735
# Epoch: 491, Loss: 3.540
# Epoch: 492, Loss: 3.932
# Epoch: 493, Loss: 3.406
# Epoch: 494, Loss: 3.400
# Epoch: 495, Loss: 3.667
# Epoch: 496, Loss: 3.357
# Epoch: 497, Loss: 3.362
# Epoch: 498, Loss: 3.016
# Epoch: 499, Loss: 3.473
# Epoch: 500, Loss: 3.006
# Epoch: 501, Loss: 3.120
# Epoch: 502, Loss: 3.338
# Epoch: 503, Loss: 3.473
# Epoch: 504, Loss: 3.421
# Epoch: 505, Loss: 3.396
# Epoch: 506, Loss: 3.676
# Epoch: 507, Loss: 3.555
# Epoch: 508, Loss: 3.737
# Epoch: 509, Loss: 3.313
# Epoch: 510, Loss: 3.047
# Epoch: 511, Loss: 4.394
# Epoch: 512, Loss: 3.122
# Epoch: 513, Loss: 3.453
# Epoch: 514, Loss: 3.386
# Epoch: 515, Loss: 3.570
# Epoch: 516, Loss: 3.176
# Epoch: 517, Loss: 3.907
# Epoch: 518, Loss: 2.985
# Epoch: 519, Loss: 3.715
# Epoch: 520, Loss: 3.662
# Epoch: 521, Loss: 3.414
# Epoch: 522, Loss: 3.350
# Epoch: 523, Loss: 3.228
# Epoch: 524, Loss: 4.041
# Epoch: 525, Loss: 3.968
# Epoch: 526, Loss: 3.301
# Epoch: 527, Loss: 3.652
# Epoch: 528, Loss: 3.439
# Epoch: 529, Loss: 3.214
# Epoch: 530, Loss: 3.866
# Epoch: 531, Loss: 3.519
# Epoch: 532, Loss: 3.773
# Epoch: 533, Loss: 3.681
# Epoch: 534, Loss: 3.228
# Epoch: 535, Loss: 3.463
# Epoch: 536, Loss: 3.649
# Epoch: 537, Loss: 3.534
# Epoch: 538, Loss: 3.324
# Epoch: 539, Loss: 3.811
# Epoch: 540, Loss: 3.409
# Epoch: 541, Loss: 3.413
# Epoch: 542, Loss: 3.531
# Epoch: 543, Loss: 3.569
# Epoch: 544, Loss: 2.842
# Epoch: 545, Loss: 3.631
# Epoch: 546, Loss: 3.069
# Epoch: 547, Loss: 3.491
# Epoch: 548, Loss: 3.311
# Epoch: 549, Loss: 3.805
# Epoch: 550, Loss: 3.103
# Epoch: 551, Loss: 3.736
# Epoch: 552, Loss: 3.001
# Epoch: 553, Loss: 2.927
# Epoch: 554, Loss: 2.877
# Epoch: 555, Loss: 3.381
# Epoch: 556, Loss: 3.615
# Epoch: 557, Loss: 3.506
# Epoch: 558, Loss: 3.205
# Epoch: 559, Loss: 3.439
# Epoch: 560, Loss: 2.990
# Epoch: 561, Loss: 3.886
# Epoch: 562, Loss: 3.102
# Epoch: 563, Loss: 3.589
# Epoch: 564, Loss: 3.482
# Epoch: 565, Loss: 3.092
# Epoch: 566, Loss: 3.484
# Epoch: 567, Loss: 3.564
# Epoch: 568, Loss: 3.447
# Epoch: 569, Loss: 4.042
# Epoch: 570, Loss: 3.339
# Epoch: 571, Loss: 3.187
# Epoch: 572, Loss: 3.234
# Epoch: 573, Loss: 3.145
# Epoch: 574, Loss: 3.749
# Epoch: 575, Loss: 3.270
# Epoch: 576, Loss: 3.523
# Epoch: 577, Loss: 3.540
# Epoch: 578, Loss: 3.594
# Epoch: 579, Loss: 3.714
# Epoch: 580, Loss: 3.050
# Epoch: 581, Loss: 3.122
# Epoch: 582, Loss: 3.214
# Epoch: 583, Loss: 3.457
# Epoch: 584, Loss: 4.063
# Epoch: 585, Loss: 3.427
# Epoch: 586, Loss: 3.776
# Epoch: 587, Loss: 3.373
# Epoch: 588, Loss: 3.150
# Epoch: 589, Loss: 3.344
# Epoch: 590, Loss: 3.579
# Epoch: 591, Loss: 3.234
# Epoch: 592, Loss: 3.846
# Epoch: 593, Loss: 3.479
# Epoch: 594, Loss: 3.130
# Epoch: 595, Loss: 3.442
# Epoch: 596, Loss: 3.226
# Epoch: 597, Loss: 3.578
# Epoch: 598, Loss: 3.371
# Epoch: 599, Loss: 3.465
# Epoch: 600, Loss: 3.094
# Epoch: 601, Loss: 3.180
# Epoch: 602, Loss: 3.413
# Epoch: 603, Loss: 2.766
# Epoch: 604, Loss: 3.147
# Epoch: 605, Loss: 3.024
# Epoch: 606, Loss: 2.937
# Epoch: 607, Loss: 3.298
# Epoch: 608, Loss: 3.112
# Epoch: 609, Loss: 3.135
# Epoch: 610, Loss: 3.515
# Epoch: 611, Loss: 3.373
# Epoch: 612, Loss: 3.592
# Epoch: 613, Loss: 3.038
# Epoch: 614, Loss: 3.995
# Epoch: 615, Loss: 3.741
# Epoch: 616, Loss: 3.322
# Epoch: 617, Loss: 2.936
# Epoch: 618, Loss: 3.759
# Epoch: 619, Loss: 3.780
# Epoch: 620, Loss: 3.217
# Epoch: 621, Loss: 3.595
# Epoch: 622, Loss: 3.439
# Epoch: 623, Loss: 4.022
# Epoch: 624, Loss: 3.139
# Epoch: 625, Loss: 3.862
# Epoch: 626, Loss: 3.228
# Epoch: 627, Loss: 3.389
# Epoch: 628, Loss: 3.284
# Epoch: 629, Loss: 2.950
# Epoch: 630, Loss: 2.892
# Epoch: 631, Loss: 3.069
# Epoch: 632, Loss: 3.513
# Epoch: 633, Loss: 3.684
# Epoch: 634, Loss: 2.974
# Epoch: 635, Loss: 2.893
# Epoch: 636, Loss: 2.987
# Epoch: 637, Loss: 3.020
# Epoch: 638, Loss: 3.522
# Epoch: 639, Loss: 3.575
# Epoch: 640, Loss: 3.196
# Epoch: 641, Loss: 3.593
# Epoch: 642, Loss: 3.419
# Epoch: 643, Loss: 3.451
# Epoch: 644, Loss: 3.020
# Epoch: 645, Loss: 3.363
# Epoch: 646, Loss: 3.038
# Epoch: 647, Loss: 3.010
# Epoch: 648, Loss: 3.254
# Epoch: 649, Loss: 3.264
# Epoch: 650, Loss: 3.416
# Epoch: 651, Loss: 3.395
# Epoch: 652, Loss: 3.318
# Epoch: 653, Loss: 3.718
# Epoch: 654, Loss: 3.487
# Epoch: 655, Loss: 3.380
# Epoch: 656, Loss: 2.831
# Epoch: 657, Loss: 3.042
# Epoch: 658, Loss: 3.052
# Epoch: 659, Loss: 3.136
# Epoch: 660, Loss: 3.897
# Epoch: 661, Loss: 3.312
# Epoch: 662, Loss: 3.262
# Epoch: 663, Loss: 3.477
# Epoch: 664, Loss: 3.028
# Epoch: 665, Loss: 2.999
# Epoch: 666, Loss: 3.528
# Epoch: 667, Loss: 3.579
# Epoch: 668, Loss: 3.549
# Epoch: 669, Loss: 2.976
# Epoch: 670, Loss: 3.113
# Epoch: 671, Loss: 3.188
# Epoch: 672, Loss: 3.029
# Epoch: 673, Loss: 3.579
# Epoch: 674, Loss: 3.811
# Epoch: 675, Loss: 3.167
# Epoch: 676, Loss: 3.046
# Epoch: 677, Loss: 2.949
# Epoch: 678, Loss: 3.867
# Epoch: 679, Loss: 3.382
# Epoch: 680, Loss: 3.513
# Epoch: 681, Loss: 3.495
# Epoch: 682, Loss: 3.283
# Epoch: 683, Loss: 3.597
# Epoch: 684, Loss: 3.232
# Epoch: 685, Loss: 3.412
# Epoch: 686, Loss: 2.999
# Epoch: 687, Loss: 3.424
# Epoch: 688, Loss: 3.032
# Epoch: 689, Loss: 3.783
# Epoch: 690, Loss: 3.050
# Epoch: 691, Loss: 3.153
# Epoch: 692, Loss: 3.335
# Epoch: 693, Loss: 3.002
# Epoch: 694, Loss: 2.844
# Epoch: 695, Loss: 4.254
# Epoch: 696, Loss: 3.191
# Epoch: 697, Loss: 3.074
# Epoch: 698, Loss: 3.277
# Epoch: 699, Loss: 3.078
# Epoch: 700, Loss: 2.937
# Epoch: 701, Loss: 3.353
# Epoch: 702, Loss: 3.080
# Epoch: 703, Loss: 2.816
# Epoch: 704, Loss: 3.231
# Epoch: 705, Loss: 3.171
# Epoch: 706, Loss: 3.332
# Epoch: 707, Loss: 3.145
# Epoch: 708, Loss: 2.931
# Epoch: 709, Loss: 3.418
# Epoch: 710, Loss: 2.934
# Epoch: 711, Loss: 3.234
# Epoch: 712, Loss: 3.063
# Epoch: 713, Loss: 3.122
# Epoch: 714, Loss: 3.374
# Epoch: 715, Loss: 3.079
# Epoch: 716, Loss: 3.148
# Epoch: 717, Loss: 3.302
# Epoch: 718, Loss: 3.032
# Epoch: 719, Loss: 3.030
# Epoch: 720, Loss: 2.736
# Epoch: 721, Loss: 2.757
# Epoch: 722, Loss: 3.156
# Epoch: 723, Loss: 3.097
# Epoch: 724, Loss: 3.099
# Epoch: 725, Loss: 3.256
# Epoch: 726, Loss: 3.028
# Epoch: 727, Loss: 3.185
# Epoch: 728, Loss: 3.003
# Epoch: 729, Loss: 2.722
# Epoch: 730, Loss: 3.659
# Epoch: 731, Loss: 3.374
# Epoch: 732, Loss: 3.045
# Epoch: 733, Loss: 3.286
# Epoch: 734, Loss: 3.117
# Epoch: 735, Loss: 3.151
# Epoch: 736, Loss: 3.159
# Epoch: 737, Loss: 3.170
# Epoch: 738, Loss: 3.254
# Epoch: 739, Loss: 3.417
# Epoch: 740, Loss: 2.793
# Epoch: 741, Loss: 3.121
# Epoch: 742, Loss: 3.492
# Epoch: 743, Loss: 3.291
# Epoch: 744, Loss: 2.956
# Epoch: 745, Loss: 3.312
# Epoch: 746, Loss: 3.144
# Epoch: 747, Loss: 3.334
# Epoch: 748, Loss: 3.350
# Epoch: 749, Loss: 3.110
# Epoch: 750, Loss: 3.058
# Epoch: 751, Loss: 2.777
# Epoch: 752, Loss: 3.098
# Epoch: 753, Loss: 2.954
# Epoch: 754, Loss: 3.091
# Epoch: 755, Loss: 2.858
# Epoch: 756, Loss: 3.403
# Epoch: 757, Loss: 3.254
# Epoch: 758, Loss: 3.583
# Epoch: 759, Loss: 2.958
# Epoch: 760, Loss: 2.718
# Epoch: 761, Loss: 3.284
# Epoch: 762, Loss: 3.245
# Epoch: 763, Loss: 2.690
# Epoch: 764, Loss: 3.028
# Epoch: 765, Loss: 3.174
# Epoch: 766, Loss: 2.917
# Epoch: 767, Loss: 3.466
# Epoch: 768, Loss: 2.912
# Epoch: 769, Loss: 3.060
# Epoch: 770, Loss: 2.916
# Epoch: 771, Loss: 3.211
# Epoch: 772, Loss: 3.169
# Epoch: 773, Loss: 4.145
# Epoch: 774, Loss: 3.287
# Epoch: 775, Loss: 2.749
# Epoch: 776, Loss: 2.898
# Epoch: 777, Loss: 2.907
# Epoch: 778, Loss: 3.192
# Epoch: 779, Loss: 3.217
# Epoch: 780, Loss: 3.381
# Epoch: 781, Loss: 2.674
# Epoch: 782, Loss: 2.947
# Epoch: 783, Loss: 2.665
# Epoch: 784, Loss: 2.904
# Epoch: 785, Loss: 3.068
# Epoch: 786, Loss: 3.281
# Epoch: 787, Loss: 2.957
# Epoch: 788, Loss: 2.893
# Epoch: 789, Loss: 2.736
# Epoch: 790, Loss: 2.773
# Epoch: 791, Loss: 2.553
# Epoch: 792, Loss: 2.991
# Epoch: 793, Loss: 2.561
# Epoch: 794, Loss: 3.334
# Epoch: 795, Loss: 3.105
# Epoch: 796, Loss: 3.228
# Epoch: 797, Loss: 3.229
# Epoch: 798, Loss: 2.759
# Epoch: 799, Loss: 3.224
# Epoch: 800, Loss: 2.895
# Epoch: 801, Loss: 3.677
# Epoch: 802, Loss: 3.290
# Epoch: 803, Loss: 3.056
# Epoch: 804, Loss: 3.030
# Epoch: 805, Loss: 3.274
# Epoch: 806, Loss: 2.954
# Epoch: 807, Loss: 3.573
# Epoch: 808, Loss: 3.240
# Epoch: 809, Loss: 3.194
# Epoch: 810, Loss: 2.766
# Epoch: 811, Loss: 3.276
# Epoch: 812, Loss: 3.167
# Epoch: 813, Loss: 3.225
# Epoch: 814, Loss: 3.018
# Epoch: 815, Loss: 3.141
# Epoch: 816, Loss: 2.734
# Epoch: 817, Loss: 3.015
# Epoch: 818, Loss: 2.851
# Epoch: 819, Loss: 3.232
# Epoch: 820, Loss: 3.176
# Epoch: 821, Loss: 2.792
# Epoch: 822, Loss: 2.747
# Epoch: 823, Loss: 2.857
# Epoch: 824, Loss: 2.913
# Epoch: 825, Loss: 2.992
# Epoch: 826, Loss: 3.021
# Epoch: 827, Loss: 3.571
# Epoch: 828, Loss: 2.914
# Epoch: 829, Loss: 3.088
# Epoch: 830, Loss: 2.875
# Epoch: 831, Loss: 3.438
# Epoch: 832, Loss: 3.154
# Epoch: 833, Loss: 2.997
# Epoch: 834, Loss: 2.965
# Epoch: 835, Loss: 3.393
# Epoch: 836, Loss: 3.276
# Epoch: 837, Loss: 2.491
# Epoch: 838, Loss: 2.904
# Epoch: 839, Loss: 2.976
# Epoch: 840, Loss: 3.131
# Epoch: 841, Loss: 2.917
# Epoch: 842, Loss: 3.552
# Epoch: 843, Loss: 2.569
# Epoch: 844, Loss: 3.234
# Epoch: 845, Loss: 2.849
# Epoch: 846, Loss: 2.559
# Epoch: 847, Loss: 2.981
# Epoch: 848, Loss: 2.655
# Epoch: 849, Loss: 2.984
# Epoch: 850, Loss: 2.987
# Epoch: 851, Loss: 3.151
# Epoch: 852, Loss: 3.169
# Epoch: 853, Loss: 3.196
# Epoch: 854, Loss: 3.406
# Epoch: 855, Loss: 3.260
# Epoch: 856, Loss: 2.774
# Epoch: 857, Loss: 2.951
# Epoch: 858, Loss: 3.101
# Epoch: 859, Loss: 2.888
# Epoch: 860, Loss: 3.122
# Epoch: 861, Loss: 2.874
# Epoch: 862, Loss: 3.249
# Epoch: 863, Loss: 3.109
# Epoch: 864, Loss: 3.021
# Epoch: 865, Loss: 3.280
# Epoch: 866, Loss: 2.879
# Epoch: 867, Loss: 3.462
# Epoch: 868, Loss: 3.058
# Epoch: 869, Loss: 2.978
# Epoch: 870, Loss: 3.343
# Epoch: 871, Loss: 2.859
# Epoch: 872, Loss: 3.085
# Epoch: 873, Loss: 2.958
# Epoch: 874, Loss: 2.940
# Epoch: 875, Loss: 3.239
# Epoch: 876, Loss: 3.064
# Epoch: 877, Loss: 2.977
# Epoch: 878, Loss: 3.303
# Epoch: 879, Loss: 2.926
# Epoch: 880, Loss: 2.874
# Epoch: 881, Loss: 2.596
# Epoch: 882, Loss: 3.418
# Epoch: 883, Loss: 3.103
# Epoch: 884, Loss: 3.142
# Epoch: 885, Loss: 3.106
# Epoch: 886, Loss: 3.125
# Epoch: 887, Loss: 2.957
# Epoch: 888, Loss: 2.845
# Epoch: 889, Loss: 3.256
# Epoch: 890, Loss: 2.843
# Epoch: 891, Loss: 3.058
# Epoch: 892, Loss: 2.727
# Epoch: 893, Loss: 2.564
# Epoch: 894, Loss: 2.691
# Epoch: 895, Loss: 2.912
# Epoch: 896, Loss: 2.561
# Epoch: 897, Loss: 3.360
# Epoch: 898, Loss: 2.482
# Epoch: 899, Loss: 2.908
# Epoch: 900, Loss: 3.200
# Epoch: 901, Loss: 3.023
# Epoch: 902, Loss: 2.532
# Epoch: 903, Loss: 2.946
# Epoch: 904, Loss: 2.756
# Epoch: 905, Loss: 2.901
# Epoch: 906, Loss: 3.301
# Epoch: 907, Loss: 3.015
# Epoch: 908, Loss: 2.941
# Epoch: 909, Loss: 2.737
# Epoch: 910, Loss: 3.121
# Epoch: 911, Loss: 2.922
# Epoch: 912, Loss: 2.831
# Epoch: 913, Loss: 3.305
# Epoch: 914, Loss: 2.649
# Epoch: 915, Loss: 2.956
# Epoch: 916, Loss: 3.159
# Epoch: 917, Loss: 2.812
# Epoch: 918, Loss: 3.197
# Epoch: 919, Loss: 2.538
# Epoch: 920, Loss: 2.913
# Epoch: 921, Loss: 3.082
# Epoch: 922, Loss: 3.209
# Epoch: 923, Loss: 3.021
# Epoch: 924, Loss: 2.563
# Epoch: 925, Loss: 3.338
# Epoch: 926, Loss: 2.583
# Epoch: 927, Loss: 3.374
# Epoch: 928, Loss: 2.937
# Epoch: 929, Loss: 3.034
# Epoch: 930, Loss: 3.076
# Epoch: 931, Loss: 3.078
# Epoch: 932, Loss: 2.738
# Epoch: 933, Loss: 2.633
# Epoch: 934, Loss: 3.001
# Epoch: 935, Loss: 2.897
# Epoch: 936, Loss: 2.637
# Epoch: 937, Loss: 3.102
# Epoch: 938, Loss: 2.627
# Epoch: 939, Loss: 2.812
# Epoch: 940, Loss: 2.542
# Epoch: 941, Loss: 2.965
# Epoch: 942, Loss: 3.362
# Epoch: 943, Loss: 2.884
# Epoch: 944, Loss: 2.604
# Epoch: 945, Loss: 3.033
# Epoch: 946, Loss: 3.381
# Epoch: 947, Loss: 3.075
# Epoch: 948, Loss: 2.751
# Epoch: 949, Loss: 2.851
# Epoch: 950, Loss: 2.969
# Epoch: 951, Loss: 3.018
# Epoch: 952, Loss: 3.192
# Epoch: 953, Loss: 2.975
# Epoch: 954, Loss: 3.330
# Epoch: 955, Loss: 3.157
# Epoch: 956, Loss: 3.567
# Epoch: 957, Loss: 2.539
# Epoch: 958, Loss: 2.508
# Epoch: 959, Loss: 2.600
# Epoch: 960, Loss: 2.699
# Epoch: 961, Loss: 3.464
# Epoch: 962, Loss: 2.896
# Epoch: 963, Loss: 2.914
# Epoch: 964, Loss: 3.070
# Epoch: 965, Loss: 3.043
# Epoch: 966, Loss: 3.033
# Epoch: 967, Loss: 3.686
# Epoch: 968, Loss: 2.879
# Epoch: 969, Loss: 3.191
# Epoch: 970, Loss: 2.876
# Epoch: 971, Loss: 3.204
# Epoch: 972, Loss: 3.246
# Epoch: 973, Loss: 2.856
# Epoch: 974, Loss: 3.071
# Epoch: 975, Loss: 2.989
# Epoch: 976, Loss: 3.191
# Epoch: 977, Loss: 2.392
# Epoch: 978, Loss: 3.268
# Epoch: 979, Loss: 2.970
# Epoch: 980, Loss: 2.911
# Epoch: 981, Loss: 3.208
# Epoch: 982, Loss: 3.121
# Epoch: 983, Loss: 2.855
# Epoch: 984, Loss: 2.693
# Epoch: 985, Loss: 3.123
# Epoch: 986, Loss: 2.971
# Epoch: 987, Loss: 2.621
# Epoch: 988, Loss: 2.972
# Epoch: 989, Loss: 2.719
# Epoch: 990, Loss: 3.056
# Epoch: 991, Loss: 2.653
# Epoch: 992, Loss: 2.826
# Epoch: 993, Loss: 2.632
# Epoch: 994, Loss: 2.948
# Epoch: 995, Loss: 3.345
# Epoch: 996, Loss: 2.456
# Epoch: 997, Loss: 3.282
# Epoch: 998, Loss: 3.266
# Epoch: 999, Loss: 2.840
# Epoch: 1000, Loss: 2.883
# Epoch: 1001, Loss: 2.680
# Epoch: 1002, Loss: 2.653
# Epoch: 1003, Loss: 3.098
# Epoch: 1004, Loss: 2.605
# Epoch: 1005, Loss: 3.048
# Epoch: 1006, Loss: 2.913
# Epoch: 1007, Loss: 3.256
# Epoch: 1008, Loss: 2.574
# Epoch: 1009, Loss: 2.894
# Epoch: 1010, Loss: 3.252
# Epoch: 1011, Loss: 2.812
# Epoch: 1012, Loss: 2.874
# Epoch: 1013, Loss: 2.763
# Epoch: 1014, Loss: 2.581
# Epoch: 1015, Loss: 3.070
# Epoch: 1016, Loss: 2.931
# Epoch: 1017, Loss: 3.457
# Epoch: 1018, Loss: 3.018
# Epoch: 1019, Loss: 3.238
# Epoch: 1020, Loss: 3.151
# Epoch: 1021, Loss: 2.986
# Epoch: 1022, Loss: 3.260
# Epoch: 1023, Loss: 3.344
# Epoch: 1024, Loss: 3.255
# Epoch: 1025, Loss: 2.533
# Epoch: 1026, Loss: 2.505
# Epoch: 1027, Loss: 2.403
# Epoch: 1028, Loss: 2.959
# Epoch: 1029, Loss: 3.011
# Epoch: 1030, Loss: 2.768
# Epoch: 1031, Loss: 3.098
# Epoch: 1032, Loss: 2.816
# Epoch: 1033, Loss: 2.702
# Epoch: 1034, Loss: 3.165
# Epoch: 1035, Loss: 3.130
# Epoch: 1036, Loss: 2.958
# Epoch: 1037, Loss: 2.808
# Epoch: 1038, Loss: 3.383
# Epoch: 1039, Loss: 3.101
# Epoch: 1040, Loss: 2.953
# Epoch: 1041, Loss: 2.594
# Epoch: 1042, Loss: 2.734
# Epoch: 1043, Loss: 2.939
# Epoch: 1044, Loss: 3.055
# Epoch: 1045, Loss: 3.070
# Epoch: 1046, Loss: 2.780
# Epoch: 1047, Loss: 3.192
# Epoch: 1048, Loss: 2.909
# Epoch: 1049, Loss: 2.943
# Epoch: 1050, Loss: 2.489
# Epoch: 1051, Loss: 3.401
# Epoch: 1052, Loss: 2.938
# Epoch: 1053, Loss: 2.746
# Epoch: 1054, Loss: 2.967
# Epoch: 1055, Loss: 3.009
# Epoch: 1056, Loss: 2.635
# Epoch: 1057, Loss: 3.170
# Epoch: 1058, Loss: 2.681
# Epoch: 1059, Loss: 2.684
# Epoch: 1060, Loss: 2.621
# Epoch: 1061, Loss: 3.051
# Epoch: 1062, Loss: 2.874
# Epoch: 1063, Loss: 2.593
# Epoch: 1064, Loss: 2.702
# Epoch: 1065, Loss: 3.058
# Epoch: 1066, Loss: 2.957
# Epoch: 1067, Loss: 2.810
# Epoch: 1068, Loss: 2.447
# Epoch: 1069, Loss: 3.107
# Epoch: 1070, Loss: 3.097
# Epoch: 1071, Loss: 2.769
# Epoch: 1072, Loss: 2.959
# Epoch: 1073, Loss: 2.884
# Epoch: 1074, Loss: 2.360
# Epoch: 1075, Loss: 2.818
# Epoch: 1076, Loss: 2.944
# Epoch: 1077, Loss: 3.402
# Epoch: 1078, Loss: 2.911
# Epoch: 1079, Loss: 3.058
# Epoch: 1080, Loss: 2.737
# Epoch: 1081, Loss: 3.180
# Epoch: 1082, Loss: 2.773
# Epoch: 1083, Loss: 2.999
# Epoch: 1084, Loss: 2.986
# Epoch: 1085, Loss: 2.900
# Epoch: 1086, Loss: 2.952
# Epoch: 1087, Loss: 3.006
# Epoch: 1088, Loss: 3.146
# Epoch: 1089, Loss: 2.640
# Epoch: 1090, Loss: 2.207
